# %%
#hamming distance

# %%
# %run loadAndExtractPieces.ipynb
# Out:
# Found 384 files belonging to 1 classes.

# %%
import math
from itertools import permutations
import numpy as np
import random

def hammingDist():
    pList = list(permutations(range(1,10)))
    
    sample = random.sample(pList,10)
        
    print(sample)
   
    
    
    #p = []
    #i = 1

    #while (i <= 100):
    
    #p.extend(j)
    #print(j)
    print("before: ", len(pList))
    

    for i in range(0,len(pList)):
        for j in range(0,len(sample)):
        #print([pList[i]], j)
            if pList[i] == sample[j]:
                pList.remove(pList[i])
                print("after: ", len(pList))
        else:
            break
        
    return False

# %%
hammingDist()
# Out:
# [(6, 3, 2, 5, 7, 9, 4, 8, 1), (2, 3, 7, 9, 1, 8, 4, 6, 5), (6, 3, 8, 2, 7, 5, 4, 9, 1), (1, 8, 6, 7, 9, 3, 2, 5, 4), (9, 2, 3, 5, 4, 1, 6, 7, 8), (2, 3, 1, 6, 4, 8, 5, 9, 7), (9, 7, 3, 1, 6, 4, 2, 5, 8), (3, 7, 1, 9, 4, 6, 5, 8, 2), (6, 3, 2, 4, 5, 1, 9, 7, 8), (7, 3, 5, 1, 6, 9, 8, 2, 4)]
# before:  362880
# False

# %%
#### SIAMESE NEURAL NETWORK

# %%
#train_data[2][2].shape

# %%
def rand_perm():
    p = list(permutations(range(1,10)))
    randP = np.random.randint(0, len(pList))
    return (pList[randP])

randPerm = rand_perm()

# %%
print(randPerm)
print(randPerm[5])
# Out:
# (3, 1, 5, 8, 6, 4, 7, 9, 2)
# 4

# %%
# import the necessary packages
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras import Input

inputShape = (66,66,3)

# %%
def siamese_model(input_shape):
    
    inputs = Input(inputShape)


    p = layers.Conv2D(96, (11,11), activation="relu", strides=2,input_shape = inputShape)(inputs)
    p = layers.MaxPooling2D((3,3), strides = 2)(p)
    p = layers.Conv2D(256, (5,5), strides = 1, padding = "same", activation = "relu")(p)
    p = layers.MaxPooling2D((3,3), strides = 2)(p)
    p = layers.Conv2D(384, (3,3), strides = 1, padding = "same", activation = "relu")(p)
    p = layers.Conv2D(384, (3,3), strides = 1, padding = "same", activation = "relu")(p)
    p = layers.Conv2D(256, (3,3), strides = 1, padding = "same", activation = "relu")(p)
    p = layers.MaxPooling2D((3,3), strides = 2)(p)
    p = layers.Dropout(0.5)(p)
    p = layers.Dense(4096, activation = "relu")(p)
    
    model = Model(inputs, p)
    
    return model

# %%
# all individual image pieces
p1 = Input(inputShape)
p2 = Input(inputShape)
p3 = Input(inputShape)
p4 = Input(inputShape)
p5 = Input(inputShape)
p6 = Input(inputShape)
p7 = Input(inputShape)
p8 = Input(inputShape)
p9 = Input(inputShape)

base = siamese_model(inputShape)

feats1 = base(p1)
feats2 = base(p2)
feats3 = base(p3)
feats4 = base(p4)
feats5 = base(p5)
feats6 = base(p6)
feats7 = base(p7)
feats8 = base(p8)
feats9 = base(p9)


merged = layers.Concatenate()([feats1, feats2, feats3, feats4, feats5, feats6, feats7, feats8, feats9])

merged = layers.Dense(4608, activation = 'relu')(merged)
merged = layers.Dense(4096, activation = 'relu')(merged)
outputs = layers.Dense(100, activation = 'softmax')(merged)

model = Model(inputs=[p1, p2, p3, p4, p5, p6, p7, p8, p9], outputs=outputs)

base.summary()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 66, 66, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 96)        34944
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 256)       614656
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 6, 6, 384)         885120
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 384)         1327488
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 256)         884992
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 2, 2, 256)         0
# _________________________________________________________________
# dense (Dense)                (None, 2, 2, 4096)        1052672
# =================================================================
# Total params: 4,799,872
# Trainable params: 4,799,872
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 66, 66, 3)]  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 66, 66, 3)]  0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 66, 66, 3)]  0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 66, 66, 3)]  0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 66, 66, 3)]  0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 66, 66, 3)]  0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 66, 66, 3)]  0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 66, 66, 3)]  0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 66, 66, 3)]  0
# __________________________________________________________________________________________________
# model (Functional)              (None, 2, 2, 4096)   4799872     input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_4[0][0]
#                                                                  input_5[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
#                                                                  input_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 36864)  0           model[0][0]
#                                                                  model[1][0]
#                                                                  model[2][0]
#                                                                  model[3][0]
#                                                                  model[4][0]
#                                                                  model[5][0]
#                                                                  model[6][0]
#                                                                  model[7][0]
#                                                                  model[8][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2, 2, 4608)   169873920   concatenate[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2, 2, 4096)   18878464    dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2, 2, 100)    409700      dense_2[0][0]
# ==================================================================================================
# Total params: 193,961,956
# Trainable params: 193,961,956
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(base, "my_first_model_with_shape_info.png", show_shapes=True)

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
#print(valid_data[:6][0])
#data = np.expand_dims(np.array(valid_data), axis = 0)
#valid_data = np.reshape(1,66,66,3)

#valid_data.reshape(1,66,66,3)
#plt.figure(figsize=(3,3))
#plt.imshow(np.array(valid_data[:6]).astype('uint16'))
#valid_data.dtype

# %%
history = model.fit(
    ([valid_data[10][0], 
     valid_data[10][1], 
     valid_data[10][2], 
     valid_data[10][3], 
     valid_data[10][4],
     valid_data[10][5],
     valid_data[10][6],
     valid_data[10][7],
     valid_data[10][8]]),
    label_data,
    batch_size = 50,
    epochs=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-4bdafa89b4bb> in <module>
# ----> 1 history = model.fit(
#       2     ([valid_data[10][0],
#       3      valid_data[10][1],
#       4      valid_data[10][2],
#       5      valid_data[10][3],
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1048          training_utils.RespectCompiledTrainableState(self):
#    1049       # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1050       data_handler = data_adapter.DataHandler(
#    1051           x=x,
#    1052           y=y,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1098
#    1099     adapter_cls = select_data_adapter(x, y)
# -> 1100     self._adapter = adapter_cls(
#    1101         x,
#    1102         y,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     272
#     273     num_samples = set(int(i.shape[0]) for i in nest.flatten(inputs)).pop()
# --> 274     _check_data_cardinality(inputs)
#     275
#     276     # If batch_size is not passed but steps is, calculate from the input data.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in _check_data_cardinality(data)
#    1527           label, ", ".join(str(i.shape[0]) for i in nest.flatten(single_data)))
#    1528     msg += "Make sure all arrays contain the same number of samples."
# -> 1529     raise ValueError(msg)
#    1530
#    1531
#
# ValueError: Data cardinality is ambiguous:
#   x sizes: 66, 66, 66, 66, 66, 66, 66, 66, 66
#   y sizes: 1
# Make sure all arrays contain the same number of samples.
